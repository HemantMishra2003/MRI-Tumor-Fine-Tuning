# %%
from tensorflow.keras.models import load_model
import cv2
import numpy as np

# 1. Loading  the saved model
model = load_model("best_model.keras")

# 2. Load + preprocess the test image
img = cv2.imread("Te-pi_0027.jpg")   # inserting my image path which we wants t predict
img = cv2.resize(img, (224, 224))    # EfficientNet image size
img = img / 255.0                     # normalization
img = np.expand_dims(img, axis=0)

# 3. Prediction
pred = model.predict(img)
print("Raw Prediction:", pred)

# 4. Map to class names
classes = ["Glioma", "Meningioma", "Pituitary", "No Tumor"] 
predicted_class = classes[np.argmax(pred)]
print("Predicted Class:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Raw Prediction: [[0.8075502  0.02978303 0.08110812 0.08155862]]
# Predicted Class: Glioma
